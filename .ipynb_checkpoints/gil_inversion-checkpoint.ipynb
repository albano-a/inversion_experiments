# %%
import numpy as np
import pylops
from pylops.utils.wavelets import ricker
import matplotlib.pyplot as plt
import ipywidgets as widgets
import segyio
import cigvis
from cigvis import colormap
import scienceplots
plt.style.use(["notebook"])


petrel = colormap.cmap_to_mpl("Petrel")

# %% [markdown]
# # Loading seismic

# %%
# loading seg-y

SEGY_FILE_PATH = "./raw_data/ABL_BASE_FULL_TIME_OVERBURDENCOMP_3D_crop.sgy"
LFM_FILE_PATH = "./raw_data/TIME_LOWFREQ_3ms_ONLYWELLS_17W_500x250_N1_crop.sgy"

# %%
import numpy as np
import segyio

def load_seismic_cube(path, il_byte=189, xl_byte=193, verbose=True):
    """Carrega SEG-Y para cubo (nil, nxl, nt)."""
    with segyio.open(path, ignore_geometry=True) as f:
        samples = np.asarray(f.samples)
        iln = f.attributes(il_byte)[:].astype(int)
        xln = f.attributes(xl_byte)[:].astype(int)
        traces = segyio.collect(f.trace)[:]

    ntraces, nt = traces.shape
    if verbose:
        print(f"Number of traces: {ntraces}")
        print(f"Number of samples: {nt}")

    il_u, xl_u = np.unique(iln), np.unique(xln)
    il_min, il_max = il_u.min(), il_u.max()
    xl_min, xl_max = xl_u.min(), xl_u.max()

    dt = float(samples[1] - samples[0])
    dil = int(np.min(np.diff(il_u)))
    dxl = int(np.min(np.diff(xl_u)))
    if verbose:
        print(f"Inline: {il_min} - {il_max}")
        print(f"Xnline: {xl_min} - {xl_max}")
        print(f"Each sampling: \n Inline: {dil} \n Xnline: {dxl} \n Time: {dt}")

    ilines = np.arange(il_min, il_max + dil, dil)
    xlines = np.arange(xl_min, xl_max + dxl, dxl)
    nil, nxl = len(ilines), len(xlines)
    if verbose:
        print(f"Inline size: {nil}")
        print(f"Xnline size: {nxl}")

    lut = np.full((nil, nxl), -1, dtype=np.int32)
    lut[(iln - il_min)//dil, (xln - xl_min)//dxl] = np.arange(ntraces, dtype=np.int32)
    valid = lut >= 0
    if verbose:
        print(f"# Missing traces: {int((~valid).sum())}")

    cube = np.zeros((nil, nxl, nt), dtype=traces.dtype)
    cube[valid] = traces[lut[valid]]

    p5, p95 = np.nanpercentile(cube, [5, 95])
    if verbose:
        print(f"Cube shape: {cube.shape}")
        print(f"P5: {p5} and P95: {p95}")

    meta = dict(samples=samples, dt=dt, ilines=ilines, xlines=xlines,
                nil=nil, nxl=nxl, nt=nt, ntraces=ntraces)
    return cube, meta

cube, m = load_seismic_cube("./raw_data/ABL_BASE_FULL_TIME_OVERBURDENCOMP_3D_crop.sgy")
lfm, m_lfm = load_seismic_cube("./raw_data/TIME_LOWFREQ_3ms_ONLYWELLS_17W_500x250_N1_crop.sgy")
# Out:
# Number of traces: 243307
# Number of samples: 1614
# Inline: 970 - 1436
# Xnline: 1650 - 2170
# Each sampling:
#  Inline: 1
#  Xnline: 1
#  Time: 3.0
# Inline size: 467
# Xnline size: 521
# # Missing traces: 0
# Cube shape: (467, 521, 1614)
# P5: -128886.0625 and P95: 123214.375
# Number of traces: 243307
# Number of samples: 1614
# Inline: 970 - 1436
# Xnline: 1650 - 2170
# Each sampling:
#  Inline: 1
#  Xnline: 1
#  Time: 3.0
# Inline size: 467
# Xnline size: 521
# # Missing traces: 0
# Cube shape: (467, 521, 1614)
# P5: 0.0 and P95: 8461.9296875

# %%
inline_idx = cube.shape[0] // 2
plt.figure(figsize=(7,5))
plt.imshow(
    cube[inline_idx].T,
    aspect="auto",
    cmap=petrel,
    vmin=np.nanpercentile(cube, 5) * 4,
    vmax=np.nanpercentile(cube, 95) * 4,
)
plt.title(f"Iline {inline_idx} / il {m['ilines'][inline_idx]}")
plt.xlabel("Xline"); plt.ylabel("Time sample")
# Out:
# Text(0, 0.5, 'Time sample')

# %%
inline_idx = lfm.shape[0] // 2
plt.figure(figsize=(7,5))
plt.imshow(
    lfm[inline_idx].T,
    aspect="auto",
    cmap=petrel,
    vmin=np.nanpercentile(lfm, 5) * 4,
    vmax=np.nanpercentile(lfm, 95) * 4,
)
plt.title(f"Iline {inline_idx} / il {m_lfm['ilines'][inline_idx]}")
plt.xlabel("Xline"); plt.ylabel("Time sample")
# Out:
# Text(0, 0.5, 'Time sample')

# %% [markdown]
# # Wavelet

# %%
NFFT = 2**8 # Fixed FFT length
MAX_NT_WAV = NFFT // 2
nt_wav = 33
dt_ms = m['dt'] / 1000

# %%
idx_2000 = np.argmin(np.abs(m['samples'] - 2000))
idx_4000 = np.argmin(np.abs(m['samples'] - 4000))

print(f"Indice of sample 2000: {idx_2000}")
print(f"Indice of sample 4000: {idx_4000}")
# Out:
# Indice of sample 2000: 667
# Indice of sample 4000: 1333

# %%
# Achatando o cubo 3D
cut_data_cube = cube[:, :, idx_2000:idx_4000]
traces_panel = cut_data_cube.reshape(-1, cut_data_cube.shape[-1])
traces_panel.shape
traces_panel
# Out:
# array([[ 182182.81  ,   56497.785 , -168187.31  , ..., -141732.06  ,
#         -211525.44  , -248452.62  ],
#        [ 208395.69  ,  124312.375 ,  -85716.625 , ..., -128404.625 ,
#         -204345.31  , -247127.31  ],
#        [ 211640.94  ,  172569.19  ,   -1230.603 , ..., -111730.06  ,
#         -196118.25  , -246569.75  ],
#        ...,
#        [  -2008.9753,   -4199.551 ,   -7692.6016, ...,   10906.031 ,
#           -3833.1123,  -12390.73  ],
#        [   1663.4646,   -1137.1174,   -5681.125 , ...,   15548.203 ,
#             265.5083,  -10852.633 ],
#        [  -7758.922 ,   -6020.258 ,   -4280.75  , ...,   20850.168 ,
#            5047.3633,   -9158.488 ]], shape=(243307, 666), dtype=float32)

# %%
fft_tr = np.fft.fft(traces_panel, NFFT, axis=-1)

# Espectro médio de amplitude sobre os traços (fase zero, só usa |FFT|)
spec = np.mean(np.abs(fft_tr), axis=0)

# %%
f_axis = np.fft.fftfreq(NFFT, d=dt_ms)

wav = np.real(np.fft.ifft(spec)[:nt_wav])
wav = np.concatenate((np.flipud(wav[1:]), wav), axis=0)
wav = wav / np.max(np.abs(wav))

f_axis = f_axis[: NFFT // 2]
spec = spec[: NFFT // 2]
spec = spec / np.max(spec) # normalize

# %%
t_axis = np.arange(-nt_wav + 1, nt_wav) * dt_ms

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))


axes[0].plot(t_axis, wav, lw=2.0)
axes[0].set_title("Time")
axes[0].grid()

axes[1].plot(f_axis, spec, lw=2.0)
axes[1].set_title("Frequency")
axes[1].grid()

plt.show()

# %% [markdown]
# # Inversão Acústica (GLI)

# %%
def run_gli_acoustic(
    sein,
    lfm,
    wav,
    eps_i=1e-1,
    eps_r=5e-1,
    damp=1e-1,
    iter_lim=100,
    explicit=False,
):
    """
    sein : ndarray
        Dado sismico observado (empilhado), shape (nt0,) ou (nt0, nx, ny).
    lfm : ndarray
        Modelo de baixa frequencia de impedancia acustica, mesmo shape espacial de sein.
    wav : ndarray
        Wavelet estimada, dominio do tempo.
    eps_i : float
        Peso de damping (regularizacao Tikhonov sobre o modelo).
    eps_r : float
        Peso de blockiness (regularizacao sobre a derivada do modelo).
    damp : float
        Damping interno do solver lsqr.
    iter_lim : int
        Numero maximo de iteracoes do solver.
    explicit : bool
        Se True, usa solver denso (lstsq). Se False, usa iterativo (lsqr).

    Retorna
    -------
    aiinv : ndarray
        Impedancia acustica invertida.
    dres : ndarray
        Residuo entre dado observado e dado reproduzido pelo modelo invertido.
    """
    nt0 = sein.shape[0]
    mback = np.log(lfm)

    minv, dres = pylops.avo.poststack.PoststackInversion(
        sein, wav, m0=back,
        explicit=expl, epsI=epsi, epsR=epsr,
        returnres=True,
        **dict(damp=damp, iter_lim=itlim)
    )

    aiinv = np.exp(minv)
    return aiinv, dres

# %% [markdown]
# # Inversão Elástica (GLI)
